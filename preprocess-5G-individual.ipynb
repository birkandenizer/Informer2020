# %%
import pandas as pd
import numpy as np
import os
cwd = os.getcwd()
cwd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
SCOPE = 100

# %%
test = pd.DataFrame([(0.0, np.nan, -1.0, 1.0),
                   (np.nan, 2.0, np.nan, np.nan),
                   (2.0, 3.0, np.nan, 9.0),
                   (np.nan, 4.0, -4.0, 16.0)],
                  columns=list('abcd'))
test
# Out:
#      a    b    c     d
# 0  0.0  NaN -1.0   1.0
# 1  NaN  2.0  NaN   NaN
# 2  2.0  3.0  NaN   9.0
# 3  NaN  4.0 -4.0  16.0

# %%
#test.interpolate(method='linear', axis=0)
#df.interpolate(method='linear', limit_direction='forward', axis=0)
#test.interpolate(method='polynomial', order=2)

# %%
PATH = '/work/bde'
download = f'{PATH}/Data/5Gdataset-master/5G-production-dataset/Download/Driving/'
df_list = []
file_dir = download

for file in os.listdir(file_dir)[:]:
    print(file)
    df = pd.read_csv(file_dir+file)
    #print(df.head())
    
    df = df[['Timestamp', 'Speed', 'CellID', 'RSRP', 'RSRQ', 'SNR', 'CQI', 'RSSI', 'DL_bitrate', 'UL_bitrate', 'NRxRSRP', 'NRxRSRQ']]
    df = df.replace('-', np.nan)
    
    df['date'] = pd.to_datetime(df['Timestamp'], format="%Y.%m.%d_%H.%M.%S")
    df = df.drop(columns=['Timestamp'])

    df['CellID'] = pd.to_numeric(df['CellID'])
    df['RSRP'] = pd.to_numeric(df['RSRP'])
    df['RSRQ'] = pd.to_numeric(df['RSRQ'])
    df['SNR'] = pd.to_numeric(df['SNR'])
    df['CQI'] = pd.to_numeric(df['CQI'])
    df['RSSI'] = pd.to_numeric(df['RSSI'])
    df['DL_bitrate'] = pd.to_numeric(df['DL_bitrate'])
    df['UL_bitrate'] = pd.to_numeric(df['UL_bitrate'])
    df['NRxRSRP'] = pd.to_numeric(df['NRxRSRP'])
    df['NRxRSRQ'] = pd.to_numeric(df['NRxRSRQ'])

    #https://pandas.pydata.org/docs/reference/api/pandas.DatetimeIndex.html
    df['second'] = df['date'].dt.second
    df['minute'] = df['date'].dt.minute
    df['hour'] = df['date'].dt.hour
    df['day'] = df['date'].dt.day

    df.interpolate(method='linear', limit_direction='both', axis=0, inplace=True)
    #df.fillna(method='ffill', inplace=True)
    #df.fillna(method='ffill', inplace=True, limit=5)
    df.fillna(0, inplace=True)

    df.drop_duplicates(subset=['date'], inplace=True)
    df.sort_values('date', inplace=True)
    df.info()
    #df.info(show_counts=True)
    #print(df.head())
    #df.plot(subplots=True, layout=(3,3), figsize=(40, 25))
    #df.to_csv('5Gdataset-{}.csv'.format(file), encoding='utf-8', index=False)

    df.to_csv(f'/work/bde/Data/5Gdataset-preprocessed/{file}', encoding='utf-8', index=False)

    df_list.append(df)
# Out:
# B_2020.02.14_09.38.22.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 1453 entries, 0 to 1644
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       1453 non-null   int64
#  1   CellID      1453 non-null   int64
#  2   RSRP        1453 non-null   int64
#  3   RSRQ        1453 non-null   float64
#  4   SNR         1453 non-null   float64
#  5   CQI         1453 non-null   int64
#  6   RSSI        1453 non-null   int64
#  7   DL_bitrate  1453 non-null   int64
#  8   UL_bitrate  1453 non-null   int64
#  9   NRxRSRP     1453 non-null   float64
#  10  NRxRSRQ     1453 non-null   float64
#  11  date        1453 non-null   datetime64[ns]
#  12  second      1453 non-null   int32
#  13  minute      1453 non-null   int32
#  14  hour        1453 non-null   int32
#  15  day         1453 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(4), int64(7)
# memory usage: 170.3 KB
# B_2020.01.16_12.10.03.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 340 entries, 0 to 383
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       340 non-null    int64
#  1   CellID      340 non-null    int64
#  2   RSRP        340 non-null    int64
#  3   RSRQ        340 non-null    int64
#  4   SNR         340 non-null    float64
#  5   CQI         340 non-null    int64
#  6   RSSI        340 non-null    int64
#  7   DL_bitrate  340 non-null    int64
#  8   UL_bitrate  340 non-null    int64
#  9   NRxRSRP     340 non-null    float64
#  10  NRxRSRQ     340 non-null    float64
#  11  date        340 non-null    datetime64[ns]
#  12  second      340 non-null    int32
#  13  minute      340 non-null    int32
#  14  hour        340 non-null    int32
#  15  day         340 non-null    int32
# dtypes: datetime64[ns](1), float64(3), int32(4), int64(8)
# memory usage: 39.8 KB
# B_2020.02.13_13.03.24.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 2226 entries, 0 to 2467
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       2226 non-null   int64
#  1   CellID      2226 non-null   int64
#  2   RSRP        2226 non-null   int64
#  3   RSRQ        2226 non-null   float64
#  4   SNR         2226 non-null   float64
#  5   CQI         2226 non-null   float64
#  6   RSSI        2226 non-null   float64
#  7   DL_bitrate  2226 non-null   int64
#  8   UL_bitrate  2226 non-null   int64
#  9   NRxRSRP     2226 non-null   float64
#  10  NRxRSRQ     2226 non-null   float64
#  11  date        2226 non-null   datetime64[ns]
#  12  second      2226 non-null   int32
#  13  minute      2226 non-null   int32
#  14  hour        2226 non-null   int32
#  15  day         2226 non-null   int32
# dtypes: datetime64[ns](1), float64(6), int32(4), int64(5)
# memory usage: 260.9 KB
# B_2019.12.16_07.22.43.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 2283 entries, 0 to 2616
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       2283 non-null   int64
#  1   CellID      2283 non-null   int64
#  2   RSRP        2283 non-null   int64
#  3   RSRQ        2283 non-null   int64
#  4   SNR         2283 non-null   float64
#  5   CQI         2283 non-null   int64
#  6   RSSI        2283 non-null   float64
#  7   DL_bitrate  2283 non-null   int64
#  8   UL_bitrate  2283 non-null   int64
#  9   NRxRSRP     2283 non-null   float64
#  10  NRxRSRQ     2283 non-null   float64
#  11  date        2283 non-null   datetime64[ns]
#  12  second      2283 non-null   int32
#  13  minute      2283 non-null   int32
#  14  hour        2283 non-null   int32
#  15  day         2283 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(4), int64(7)
# memory usage: 267.5 KB
# B_2019.12.16_11.49.59.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, 0 to 400
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       342 non-null    int64
#  1   CellID      342 non-null    int64
#  2   RSRP        342 non-null    int64
#  3   RSRQ        342 non-null    int64
#  4   SNR         342 non-null    float64
#  5   CQI         342 non-null    float64
#  6   RSSI        342 non-null    float64
#  7   DL_bitrate  342 non-null    int64
#  8   UL_bitrate  342 non-null    int64
#  9   NRxRSRP     342 non-null    int64
#  10  NRxRSRQ     342 non-null    int64
#  11  date        342 non-null    datetime64[ns]
#  12  second      342 non-null    int32
#  13  minute      342 non-null    int32
#  14  hour        342 non-null    int32
#  15  day         342 non-null    int32
# dtypes: datetime64[ns](1), float64(3), int32(4), int64(8)
# memory usage: 40.1 KB
# B_2019.12.17_07.32.39.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 2295 entries, 0 to 2574
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       2295 non-null   int64
#  1   CellID      2295 non-null   int64
#  2   RSRP        2295 non-null   int64
#  3   RSRQ        2295 non-null   int64
#  4   SNR         2295 non-null   float64
#  5   CQI         2295 non-null   int64
#  6   RSSI        2295 non-null   float64
#  7   DL_bitrate  2295 non-null   int64
#  8   UL_bitrate  2295 non-null   int64
#  9   NRxRSRP     2295 non-null   float64
#  10  NRxRSRQ     2295 non-null   float64
#  11  date        2295 non-null   datetime64[ns]
#  12  second      2295 non-null   int32
#  13  minute      2295 non-null   int32
#  14  hour        2295 non-null   int32
#  15  day         2295 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(4), int64(7)
# memory usage: 268.9 KB
# B_2019.12.14_10.16.30.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 1014 entries, 0 to 1154
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       1014 non-null   int64
#  1   CellID      1014 non-null   int64
#  2   RSRP        1014 non-null   int64
#  3   RSRQ        1014 non-null   int64
#  4   SNR         1014 non-null   float64
#  5   CQI         1014 non-null   float64
#  6   RSSI        1014 non-null   float64
#  7   DL_bitrate  1014 non-null   int64
#  8   UL_bitrate  1014 non-null   int64
#  9   NRxRSRP     1014 non-null   float64
#  10  NRxRSRQ     1014 non-null   float64
#  11  date        1014 non-null   datetime64[ns]
#  12  second      1014 non-null   int32
#  13  minute      1014 non-null   int32
#  14  hour        1014 non-null   int32
#  15  day         1014 non-null   int32
# dtypes: datetime64[ns](1), float64(5), int32(4), int64(6)
# memory usage: 118.8 KB
# B_2020.01.16_09.56.56.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 1536 entries, 0 to 1740
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       1536 non-null   int64
#  1   CellID      1536 non-null   int64
#  2   RSRP        1536 non-null   int64
#  3   RSRQ        1536 non-null   int64
#  4   SNR         1536 non-null   float64
#  5   CQI         1536 non-null   int64
#  6   RSSI        1536 non-null   int64
#  7   DL_bitrate  1536 non-null   int64
#  8   UL_bitrate  1536 non-null   int64
#  9   NRxRSRP     1536 non-null   float64
#  10  NRxRSRQ     1536 non-null   float64
#  11  date        1536 non-null   datetime64[ns]
#  12  second      1536 non-null   int32
#  13  minute      1536 non-null   int32
#  14  hour        1536 non-null   int32
#  15  day         1536 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(4), int64(8)
# memory usage: 180.0 KB
# B_2019.12.16_12.27.05.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 1181 entries, 0 to 1337
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       1181 non-null   int64
#  1   CellID      1181 non-null   int64
#  2   RSRP        1181 non-null   int64
#  3   RSRQ        1181 non-null   int64
#  4   SNR         1181 non-null   float64
#  5   CQI         1181 non-null   float64
#  6   RSSI        1181 non-null   float64
#  7   DL_bitrate  1181 non-null   int64
#  8   UL_bitrate  1181 non-null   int64
#  9   NRxRSRP     1181 non-null   float64
#  10  NRxRSRQ     1181 non-null   float64
#  11  date        1181 non-null   datetime64[ns]
#  12  second      1181 non-null   int32
#  13  minute      1181 non-null   int32
#  14  hour        1181 non-null   int32
#  15  day         1181 non-null   int32
# dtypes: datetime64[ns](1), float64(5), int32(4), int64(6)
# memory usage: 138.4 KB
# B_2020.02.27_20.35.57.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 734 entries, 0 to 857
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       734 non-null    int64
#  1   CellID      734 non-null    int64
#  2   RSRP        734 non-null    int64
#  3   RSRQ        734 non-null    float64
#  4   SNR         734 non-null    float64
#  5   CQI         734 non-null    float64
#  6   RSSI        734 non-null    float64
#  7   DL_bitrate  734 non-null    int64
#  8   UL_bitrate  734 non-null    int64
#  9   NRxRSRP     734 non-null    float64
#  10  NRxRSRQ     734 non-null    float64
#  11  date        734 non-null    datetime64[ns]
#  12  second      734 non-null    int32
#  13  minute      734 non-null    int32
#  14  hour        734 non-null    int32
#  15  day         734 non-null    int32
# dtypes: datetime64[ns](1), float64(6), int32(4), int64(5)
# memory usage: 86.0 KB
# B_2020.02.27_17.30.15.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 752 entries, 0 to 865
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       752 non-null    int64
#  1   CellID      752 non-null    int64
#  2   RSRP        752 non-null    int64
#  3   RSRQ        752 non-null    float64
#  4   SNR         752 non-null    float64
#  5   CQI         752 non-null    float64
#  6   RSSI        752 non-null    float64
#  7   DL_bitrate  752 non-null    int64
#  8   UL_bitrate  752 non-null    int64
#  9   NRxRSRP     752 non-null    float64
#  10  NRxRSRQ     752 non-null    float64
#  11  date        752 non-null    datetime64[ns]
#  12  second      752 non-null    int32
#  13  minute      752 non-null    int32
#  14  hour        752 non-null    int32
#  15  day         752 non-null    int32
# dtypes: datetime64[ns](1), float64(6), int32(4), int64(5)
# memory usage: 88.1 KB
# B_2020.02.13_15.02.01.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3186 entries, 0 to 3572
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       3186 non-null   int64
#  1   CellID      3186 non-null   int64
#  2   RSRP        3186 non-null   int64
#  3   RSRQ        3186 non-null   float64
#  4   SNR         3186 non-null   float64
#  5   CQI         3186 non-null   float64
#  6   RSSI        3186 non-null   float64
#  7   DL_bitrate  3186 non-null   int64
#  8   UL_bitrate  3186 non-null   int64
#  9   NRxRSRP     3186 non-null   float64
#  10  NRxRSRQ     3186 non-null   float64
#  11  date        3186 non-null   datetime64[ns]
#  12  second      3186 non-null   int32
#  13  minute      3186 non-null   int32
#  14  hour        3186 non-null   int32
#  15  day         3186 non-null   int32
# dtypes: datetime64[ns](1), float64(6), int32(4), int64(5)
# memory usage: 373.4 KB
# B_2020.01.16_07.26.43.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 1756 entries, 0 to 1980
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       1756 non-null   int64
#  1   CellID      1756 non-null   int64
#  2   RSRP        1756 non-null   int64
#  3   RSRQ        1756 non-null   int64
#  4   SNR         1756 non-null   float64
#  5   CQI         1756 non-null   int64
#  6   RSSI        1756 non-null   int64
#  7   DL_bitrate  1756 non-null   int64
#  8   UL_bitrate  1756 non-null   int64
#  9   NRxRSRP     1756 non-null   float64
#  10  NRxRSRQ     1756 non-null   float64
#  11  date        1756 non-null   datetime64[ns]
#  12  second      1756 non-null   int32
#  13  minute      1756 non-null   int32
#  14  hour        1756 non-null   int32
#  15  day         1756 non-null   int32
# dtypes: datetime64[ns](1), float64(3), int32(4), int64(8)
# memory usage: 205.8 KB
# B_2020.02.14_07.29.00.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 1912 entries, 0 to 2138
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       1912 non-null   int64
#  1   CellID      1912 non-null   int64
#  2   RSRP        1912 non-null   int64
#  3   RSRQ        1912 non-null   float64
#  4   SNR         1912 non-null   float64
#  5   CQI         1912 non-null   float64
#  6   RSSI        1912 non-null   float64
#  7   DL_bitrate  1912 non-null   int64
#  8   UL_bitrate  1912 non-null   int64
#  9   NRxRSRP     1912 non-null   float64
#  10  NRxRSRQ     1912 non-null   float64
#  11  date        1912 non-null   datetime64[ns]
#  12  second      1912 non-null   int32
#  13  minute      1912 non-null   int32
#  14  hour        1912 non-null   int32
#  15  day         1912 non-null   int32
# dtypes: datetime64[ns](1), float64(6), int32(4), int64(5)
# memory usage: 224.1 KB
# B_2020.02.14_12.58.17.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 844 entries, 0 to 959
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       844 non-null    int64
#  1   CellID      844 non-null    int64
#  2   RSRP        844 non-null    int64
#  3   RSRQ        844 non-null    float64
#  4   SNR         844 non-null    float64
#  5   CQI         844 non-null    float64
#  6   RSSI        844 non-null    float64
#  7   DL_bitrate  844 non-null    int64
#  8   UL_bitrate  844 non-null    int64
#  9   NRxRSRP     844 non-null    int64
#  10  NRxRSRQ     844 non-null    float64
#  11  date        844 non-null    datetime64[ns]
#  12  second      844 non-null    int32
#  13  minute      844 non-null    int32
#  14  hour        844 non-null    int32
#  15  day         844 non-null    int32
# dtypes: datetime64[ns](1), float64(5), int32(4), int64(6)
# memory usage: 98.9 KB
# B_2019.12.16_14.23.32.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 2592 entries, 0 to 2886
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Speed       2592 non-null   int64
#  1   CellID      2592 non-null   int64
#  2   RSRP        2592 non-null   int64
#  3   RSRQ        2592 non-null   int64
#  4   SNR         2592 non-null   float64
#  5   CQI         2592 non-null   int64
#  6   RSSI        2592 non-null   float64
#  7   DL_bitrate  2592 non-null   int64
#  8   UL_bitrate  2592 non-null   int64
#  9   NRxRSRP     2592 non-null   float64
#  10  NRxRSRQ     2592 non-null   float64
#  11  date        2592 non-null   datetime64[ns]
#  12  second      2592 non-null   int32
#  13  minute      2592 non-null   int32
#  14  hour        2592 non-null   int32
#  15  day         2592 non-null   int32
# dtypes: datetime64[ns](1), float64(4), int32(4), int64(7)
# memory usage: 303.8 KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def multi_corr(df, feature):
    fig, ax = plt.subplots(1,3, figsize=(20, 6))

    # when the Pearson and Spearman values are not much different, 
    # our data tends to not have extreme values (outliers)
    corr1 = df.corr('pearson')[[feature]].sort_values(by=feature, ascending=False)
    corr2 = df.corr('spearman')[[feature]].sort_values(by=feature, ascending=False)

    corr3 = df.corr('kendall')[[feature]].sort_values(by=feature, ascending=False)
    #ordinal correlation (Spearman & Kendall Tau)

    sns.heatmap(corr1, ax=ax[0], annot=True)
    sns.heatmap(corr2, ax=ax[1], annot=True)
    sns.heatmap(corr3, ax=ax[2], annot=True)

# %%
multi_corr(df, 'DL_bitrate')
