# %%
import json
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
with open('test.json', 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data['rawResponse']['hits']['hits'])

# %%
data.keys()
# Out:
# dict_keys(['rawResponse', 'isPartial', 'isRunning', 'total', 'loaded', 'isRestored'])

# %%
features = []
for data in data['rawResponse']['hits']['hits']:
    features.append(data['fields'])

# %%
df = pd.json_normalize(features)
df.head()
# Out:
#   lte.lSinr gps.lat.keyword lte.lrxpacketspersecond        gps.speed  \
# 0       [9]           [0.0]                    [15]  [0.000000 km/h]
# 1       [9]           [0.0]                    [14]  [0.000000 km/h]
# 2       [9]           [0.0]                    [14]  [0.000000 km/h]
# 3       [9]           [0.0]                    [14]  [0.000000 km/h]
# 4       [7]           [0.0]                    [14]  [0.000000 km/h]
#
#   lte.lCurrentOperator lte.lEnbId gps.altitude.keyword lte.lRi  \
# 0        [vodafone.de]         []         [0.000000 m]     [2]
# 1        [vodafone.de]         []         [0.000000 m]     [2]
# 2        [vodafone.de]         []         [0.000000 m]     [2]
# 3        [vodafone.de]         []         [0.000000 m]     [2]
# 4        [vodafone.de]         []         [0.000000 m]     [2]
#
#                                     geo_point lte.lrxerrorspersecond  \
# 0  [{'coordinates': [0, 0], 'type': 'Point'}]                    [0]
# ...

# %%
df = df[['@timestamp', 'lte.lRsrp', 'lte.lRsrq', 'lte.lSinr', 'lte.lCqi', 'lte.lrxbitspersecond', 'lte.ltxbitspersecond', 'lte.lrxpacketspersecond', 'lte.ltxpacketspersecond']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   @timestamp               500 non-null    object
#  1   lte.lRsrp                500 non-null    object
#  2   lte.lRsrq                500 non-null    object
#  3   lte.lSinr                500 non-null    object
#  4   lte.lCqi                 500 non-null    object
#  5   lte.lrxbitspersecond     500 non-null    object
#  6   lte.ltxbitspersecond     500 non-null    object
#  7   lte.lrxpacketspersecond  500 non-null    object
#  8   lte.ltxpacketspersecond  500 non-null    object
# dtypes: object(9)
# memory usage: 35.3+ KB

# %%
df.head(50)
# Out:
#                     @timestamp lte.lRsrp lte.lRsrq lte.lSinr lte.lCqi  \
# 0   [2023-09-21T13:28:10.701Z]    [-113]    [-150]       [9]     [11]
# 1   [2023-09-21T13:28:09.691Z]    [-113]    [-150]       [9]     [10]
# 2   [2023-09-21T13:28:08.683Z]    [-113]    [-150]       [9]     [10]
# 3   [2023-09-21T13:28:07.664Z]    [-113]    [-150]       [9]     [10]
# 4   [2023-09-21T13:28:06.707Z]    [-113]    [-150]       [7]     [10]
# 5   [2023-09-21T13:28:05.715Z]    [-113]    [-150]       [7]     [10]
# 6   [2023-09-21T13:28:04.678Z]    [-113]    [-150]       [7]     [10]
# 7   [2023-09-21T13:28:03.680Z]    [-113]    [-150]       [8]      [9]
# 8   [2023-09-21T13:28:02.679Z]    [-113]    [-150]       [8]      [9]
# 9   [2023-09-21T13:28:01.680Z]    [-113]    [-150]       [8]      [9]
# 10  [2023-09-21T13:28:00.695Z]    [-114]    [-160]       [8]     [11]
# 11  [2023-09-21T13:27:59.653Z]    [-114]    [-160]       [8]     [11]
# ...
